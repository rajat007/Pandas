# %%
import pandas as pd
week1=pd.read_csv(r"D:\Data\machine-learning-master\pandas\Restaurant - Week 1 Sales.csv")
week2=pd.read_csv(r"D:\Data\machine-learning-master\pandas\Restaurant - Week 2 Sales.csv")
food=pd.read_csv(r"D:\Data\machine-learning-master\pandas\Restaurant - Foods.csv")
customer=pd.read_csv(r"D:\Data\machine-learning-master\pandas\Restaurant - Customers.csv")
Email_open=pd.read_csv(r"D:\Data\machine-learning-master\email\email_opened_table.csv")
Email_table=pd.read_csv(r"D:\Data\machine-learning-master\email\email_table.csv")
Email_link=pd.read_csv(r"D:\Data\machine-learning-master\email\link_clicked_table.csv")

# %%
week1.head()
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1
# 3          202        2
# 4          155        9

# %%
week1.merge(week2,how='inner',indicator=True,on="Customer ID")
#matching in both for inner
len(week1.merge(week2,how='inner',indicator=True,on="Customer ID"))
# Out:
# 62

# %%
merged=week1.merge(week2,how='outer',indicator=True,on="Customer ID")
#It will contain values of both week1 and week 2
merged.count()
# Out:
# Customer ID    454
# Food ID_x      257
# Food ID_y      259
# _merge         454
# dtype: int64

# %%
mask=merged["_merge"].isin(["right_only","left_only"])
merged[mask]
# Out:
#      Customer ID  Food ID_x  Food ID_y      _merge
# 1             97        4.0        NaN   left_only
# 2            658        1.0        NaN   left_only
# 3            202        2.0        NaN   left_only
# 6            213        8.0        NaN   left_only
# 7            600        1.0        NaN   left_only
# 10            71        3.0        NaN   left_only
# 11            71        8.0        NaN   left_only
# 12           174        3.0        NaN   left_only
# 13           961        9.0        NaN   left_only
# 14           966        5.0        NaN   left_only
# 15           641        4.0        NaN   left_only
# 16           288        2.0        NaN   left_only
# 17           149        4.0        NaN   left_only
# 18           954        2.0        NaN   left_only
# 19           147        9.0        NaN   left_only
# 20           147        8.0        NaN   left_only
# 23           549        6.0        NaN   left_only
# ...

# %%
food.head()
# Out:
#    Food ID   Food Item  Price
# 0        1       Sushi   3.99
# 1        2     Burrito   9.99
# 2        3        Taco   2.99
# 3        4  Quesadilla   4.25
# 4        5       Pizza   2.49

# %%
week1.merge(food,how="left",on="Food ID",sort=True)
# Out:
#      Customer ID  Food ID Food Item  Price
# 0            658        1     Sushi   3.99
# 1            600        1     Sushi   3.99
# 2            155        1     Sushi   3.99
# 3            341        1     Sushi   3.99
# 4             20        1     Sushi   3.99
# 5             77        1     Sushi   3.99
# 6            100        1     Sushi   3.99
# 7            953        1     Sushi   3.99
# 8            504        1     Sushi   3.99
# 9            323        1     Sushi   3.99
# 10           922        1     Sushi   3.99
# 11           909        1     Sushi   3.99
# 12           602        1     Sushi   3.99
# 13            74        1     Sushi   3.99
# 14           703        1     Sushi   3.99
# 15           962        1     Sushi   3.99
# 16           968        1     Sushi   3.99
# 17           190        1     Sushi   3.99
# 18           163        1     Sushi   3.99
# 19           321        1     Sushi   3.99
# 20           310        1     Sushi   3.99
# ...

# %%
customer.columns
# Out:
# Index(['ID', 'First Name', 'Last Name', 'Gender', 'Company', 'Occupation'], dtype='object')

# %%
# In case both the dataframe are having different names on which we need to apply join
(week2.merge(customer,how="left",left_on="Customer ID",right_on="ID",sort=True)).drop(['ID'],axis=1)
# Out:
#      Customer ID  Food ID   First Name  Last Name  Gender        Company  \
# 0              8        6      Frances      Adams  Female       Dabshots
# 1             13        2         Ruth    Alvarez  Female    Twitterlist
# 2             21        4       Albert      Burns    Male      Rhynoodle
# 3             24        8        Donna     Thomas  Female        Jaxbean
# 4             27        4      Jessica    Bennett  Female  Twitternation
# 5             30        4       Pamela      Hicks  Female          Ntags
# 6             35        8       Nicole    Chapman  Female        Pixonyx
# 7             39       10       Teresa   Harrison  Female            Oba
# 8             45        8         Earl   Marshall    Male          Agivu
# 9             46        6         Adam       Cole    Male          Trupe
# 10            54        8       Amanda      Berry  Female        Jaxspan
# 11            55        9        Ralph       Ford    Male     Browsezoom
# ...

# %%
Email_table=Email_table.merge(Email_link,how="left",on="email_id",indicator=True)

# %%
Email_table["Link_opened"]=Email_table["_merge"].apply({'left_only':0,'both':1}.get)

# %%
Email_table["Link_opened"]=Email_table["Link_opened"].astype(int)
Email_table["Link_opened"].value_counts()
# Out:
# 0    97881
# 1     2119
# Name: Link_opened, dtype: int64

# %%
Email_table_copy["Link_opened"].replace({'left_only':0,'both':1})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-582b9b9cec2b> in <module>()
# ----> 1 Email_table["Link_opened"].replace({'left_only':0,'both':1})
#
# c:\python37\lib\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method, axis)
#    4529
#    4530             return self.replace(to_replace, value, inplace=inplace,
# -> 4531                                 limit=limit, regex=regex)
#    4532         else:
#    4533
#
# c:\python37\lib\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method, axis)
#    4578                                                        dest_list=value,
#    4579                                                        inplace=inplace,
# -> 4580                                                        regex=regex)
#    4581
# ...
